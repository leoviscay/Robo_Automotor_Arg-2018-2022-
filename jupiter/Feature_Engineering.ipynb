# %%
import pandas as pd

# %load_ext autoreload
# %autoreload 2
import utils

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('../data/data.csv')

# %%
data.head()
# Out:
#                tramite_tipo tramite_fecha  registro_seccional_codigo  \
# 0  DENUNCIA DE ROBO O HURTO    2018-01-17                       1029
# 1  DENUNCIA DE ROBO O HURTO    2018-01-03                       1047
# 2  DENUNCIA DE ROBO O HURTO    2018-01-12                       1059
# 3  DENUNCIA DE ROBO O HURTO    2018-01-02                       1066
# 4  DENUNCIA DE ROBO O HURTO    2018-01-09                       1074
#
#   registro_seccional_descripcion registro_seccional_provincia  \
# 0        ESTEBAN ECHEVERRIA Nº 1                 Buenos Aires
# 1                     LANUS Nº 1                 Buenos Aires
# 2            MAR DEL PLATA Nº 02                 Buenos Aires
# 3                  NECOCHEA Nº 1                 Buenos Aires
# 4                     PILAR Nº 1                 Buenos Aires
#
#   automotor_origen  automotor_anio_modelo automotor_tipo_descripcion  \
# 0         Nacional                 2000.0                      SEDAN
# ...

# %% [markdown]
# ## MAPEOS

# %%
utils.asignar_tipo_tramite_id(data)
# Out:
#                                          tramite_tipo tramite_fecha  \
# 0                            DENUNCIA DE ROBO O HURTO    2018-01-17
# 1                            DENUNCIA DE ROBO O HURTO    2018-01-03
# 2                            DENUNCIA DE ROBO O HURTO    2018-01-12
# 3                            DENUNCIA DE ROBO O HURTO    2018-01-02
# 4                            DENUNCIA DE ROBO O HURTO    2018-01-09
# ...                                               ...           ...
# 337955  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337956  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337957  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
# 337958                       COMUNICACIÓN DE RECUPERO    2022-12-29
# 337959  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
#
#         registro_seccional_codigo registro_seccional_descripcion  \
# 0                            1029        ESTEBAN ECHEVERRIA Nº 1
# ...

# %%
utils.extraer_anio(data, 'tramite_fecha')
utils.extraer_mes(data, 'tramite_fecha')
# Out:
#                                          tramite_tipo tramite_fecha  \
# 0                            DENUNCIA DE ROBO O HURTO    2018-01-17
# 1                            DENUNCIA DE ROBO O HURTO    2018-01-03
# 2                            DENUNCIA DE ROBO O HURTO    2018-01-12
# 3                            DENUNCIA DE ROBO O HURTO    2018-01-02
# 4                            DENUNCIA DE ROBO O HURTO    2018-01-09
# ...                                               ...           ...
# 337955  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337956  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337957  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
# 337958                       COMUNICACIÓN DE RECUPERO    2022-12-29
# 337959  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
#
#         registro_seccional_codigo registro_seccional_descripcion  \
# 0                            1029        ESTEBAN ECHEVERRIA Nº 1
# ...

# %%
utils.mapear_origen(data, 'automotor_origen')
# Out:
#                                          tramite_tipo tramite_fecha  \
# 0                            DENUNCIA DE ROBO O HURTO    2018-01-17
# 1                            DENUNCIA DE ROBO O HURTO    2018-01-03
# 2                            DENUNCIA DE ROBO O HURTO    2018-01-12
# 3                            DENUNCIA DE ROBO O HURTO    2018-01-02
# 4                            DENUNCIA DE ROBO O HURTO    2018-01-09
# ...                                               ...           ...
# 337955  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337956  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337957  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
# 337958                       COMUNICACIÓN DE RECUPERO    2022-12-29
# 337959  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
#
#         registro_seccional_codigo registro_seccional_descripcion  \
# 0                            1029        ESTEBAN ECHEVERRIA Nº 1
# ...

# %%
data['titular_tipo_persona'].unique()
# Out:
# array(['Física', 'Jurídica'], dtype=object)

# %%
utils.mapear_tipo_persona(data,'titular_tipo_persona')
# Out:
#                                          tramite_tipo tramite_fecha  \
# 0                            DENUNCIA DE ROBO O HURTO    2018-01-17
# 1                            DENUNCIA DE ROBO O HURTO    2018-01-03
# 2                            DENUNCIA DE ROBO O HURTO    2018-01-12
# 3                            DENUNCIA DE ROBO O HURTO    2018-01-02
# 4                            DENUNCIA DE ROBO O HURTO    2018-01-09
# ...                                               ...           ...
# 337955  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337956  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337957  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
# 337958                       COMUNICACIÓN DE RECUPERO    2022-12-29
# 337959  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
#
#         registro_seccional_codigo registro_seccional_descripcion  \
# 0                            1029        ESTEBAN ECHEVERRIA Nº 1
# ...

# %%
data['titular_genero'].unique()
# Out:
# array(['Masculino', 'Femenino', 'No identificado', 'No aplica'],
#       dtype=object)

# %%
utils.mapear_genero(data, 'titular_genero')
# Out:
#                                          tramite_tipo tramite_fecha  \
# 0                            DENUNCIA DE ROBO O HURTO    2018-01-17
# 1                            DENUNCIA DE ROBO O HURTO    2018-01-03
# 2                            DENUNCIA DE ROBO O HURTO    2018-01-12
# 3                            DENUNCIA DE ROBO O HURTO    2018-01-02
# 4                            DENUNCIA DE ROBO O HURTO    2018-01-09
# ...                                               ...           ...
# 337955  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337956  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-14
# 337957  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
# 337958                       COMUNICACIÓN DE RECUPERO    2022-12-29
# 337959  DENUNCIA DE ROBO O HURTO / RETENCION INDEBIDA    2022-12-29
#
#         registro_seccional_codigo registro_seccional_descripcion  \
# 0                            1029        ESTEBAN ECHEVERRIA Nº 1
# ...
