# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2
import utils

import warnings
warnings.filterwarnings("ignore")

# %%
ruta_archivo_parquet = "../data/data_parquet.parquet"
# Leer el archivo Parquet directamente con pandas
data_parquet = pd.read_parquet(ruta_archivo_parquet)

# %%
utils.types_df(data_parquet)
# Out:
#                       nombre_campo                           tipo_datos  \
# 0                     tramite_tipo                      [<class 'str'>]
# 1                    tramite_fecha                      [<class 'str'>]
# 2        registro_seccional_codigo                      [<class 'int'>]
# 3   registro_seccional_descripcion                      [<class 'str'>]
# 4     registro_seccional_provincia                      [<class 'str'>]
# 5                 automotor_origen                      [<class 'str'>]
# 6            automotor_anio_modelo                    [<class 'float'>]
# 7       automotor_tipo_descripcion                      [<class 'str'>]
# 8           automotor_marca_codigo  [<class 'str'>, <class 'NoneType'>]
# 9      automotor_marca_descripcion                      [<class 'str'>]
# 10         automotor_modelo_codigo  [<class 'str'>, <class 'NoneType'>]
# 11    automotor_modelo_descripcion                      [<class 'str'>]
# ...

# %%
data_parquet.describe()
# Out:
#        registro_seccional_codigo  automotor_anio_modelo  automotor_uso_codigo  \
# count              337960.000000          336828.000000         337954.000000
# mean                 3151.830234            2005.197329              1.021251
# std                  4804.026505              37.407527              0.364422
# min                  1001.000000              20.000000              0.000000
# 25%                  1157.000000            1999.000000              1.000000
# 50%                  1247.000000            2007.000000              1.000000
# 75%                  2058.000000            2012.000000              1.000000
# max                 24008.000000            2022.000000              9.000000
#
#        titular_anio_nacimiento  titular_porcentaje_titularidad     tramite_id  \
# count            337864.000000                   337960.000000  337960.000000
# mean               1976.277508                       97.664694       2.230507
# ...

# %%
# Histogramas para variables numéricas
data_parquet.hist(figsize=(12, 10))
plt.show()

# Gráfico de barras para contar valores únicos en variables categóricas
sns.countplot(x='titular_genero', data=data_parquet)
plt.show()

# %%
# Mapa de calor para visualizar nulos
sns.heatmap(data_parquet.isnull(), cbar=False, cmap='viridis')
plt.show()
